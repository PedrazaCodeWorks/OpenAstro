# %% [markdown]
# # Using Ipython modules
#
# This is based from the Ipython [documentation](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html).

# %% [markdown]
# ## Audio

# %%
# Generate a sound
from IPython.display import Audio

import numpy as np
framerate = 44100
t = np.linspace(0,5,framerate*3) #3 second duration
data = np.sin(2*np.pi*220*t) + np.sin(2*np.pi*224*t)
Audio(data,rate=framerate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#add more sine waves
num_sines = 50
base_freq = 220
delta_freq = 4

data = 0
for i in range(num_sines): #sum various sine waves
    data += np.sin(2*np.pi*(base_freq+i*delta_freq)*t)

Audio(data,rate=framerate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from __future__ import print_function

# Can also do stereo or more channels
dataleft = np.sin(2*np.pi*220*t)
dataright = np.sin(2*np.pi*224*t)
Audio([dataleft, dataright],rate=framerate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# From URL
Audio(url="https://media.poetryfoundation.org/uploads/media/default/0001/08/22208df9f0df9b4e6d3e267b60d17d43f20252f3.mp3")

# From file
# Audio(filename='/path/to/sound.ogg')

# From bytes
# Audio(b'RAW_WAV_DATA..')  # From bytes
# Audio(data=b'RAW_WAV_DATA..')
# Out:
#                 <audio controls="controls" >
#                     <source src="https://media.poetryfoundation.org/uploads/media/default/0001/08/22208df9f0df9b4e6d3e267b60d17d43f20252f3.mp3" type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Image
